# %%
import yfinance as yf
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
symbols = ['BTC-USD', 'ETH-USD', 'XRP-USD', 'LTC-USD', 'BCH-USD', 'ADA-USD', 'DOT-USD', 'LINK-USD', 'XLM-USD', 'DOGE-USD']

# %%
start_date = '2018-01-01'
end_date = '2021-11-29'

# %%
lista_dfs = []
path = '/home/anna/iaemproducao/data/raw/'
for symbol in symbols:
    path_full = path + symbol + '.parquet.gzip'
    df = yf.download(symbols, start=start_date, end=end_date)
    df.to_parquet(path_full, compression='gzip')
# Out:
# [**********************50%%                      ]  5 of 10 completed
# [*********************100%%**********************]  10 of 10 completed
# [*********************100%%**********************]  10 of 10 completed
# [*********************100%%**********************]  10 of 10 completed
# [*********************100%%**********************]  10 of 10 completed
# [*********************100%%**********************]  10 of 10 completed
# [*********************100%%**********************]  10 of 10 completed
# [*********************100%%**********************]  10 of 10 completed
# [*********************100%%**********************]  10 of 10 completed
# [*********************100%%**********************]  10 of 10 completed
# [*********************100%%**********************]  10 of 10 completed

# %%
# df = yf.download(symbols, start=start_date, end=end_date)

# %%
df.tail()
# Out:
#            Adj Close                                                 \
#              ADA-USD     BCH-USD       BTC-USD  DOGE-USD    DOT-USD
# Date
# 2021-11-24  1.686423  559.120972  56280.425781  0.221825  39.369419
# 2021-11-25  1.651345  612.676819  57274.679688  0.216326  38.455948
# 2021-11-26  1.528420  555.829041  53569.765625  0.200887  34.385906
# 2021-11-27  1.546118  563.338440  54815.078125  0.205347  35.186699
# 2021-11-28  1.592855  568.336182  57248.457031  0.207472  35.765121
#
#                                                                     ...  \
#                 ETH-USD   LINK-USD     LTC-USD   XLM-USD   XRP-USD  ...
# Date                                                                ...
# 2021-11-24  4239.981445  26.259172  209.806595  0.333267  1.042075  ...
# 2021-11-25  4274.743164  26.185106  215.634979  0.331961  1.031888  ...
# 2021-11-26  4030.908936  23.856281  194.874649  0.327930  0.936350  ...
# ...

# %%
df.isnull().sum()
# Out:
# Adj Close  ADA-USD       0
#            BCH-USD       0
#            BTC-USD       0
#            DOGE-USD      0
#            DOT-USD     962
#            ETH-USD       0
#            LINK-USD      0
#            LTC-USD       0
#            XLM-USD       0
#            XRP-USD       0
# Close      ADA-USD       0
#            BCH-USD       0
#            BTC-USD       0
#            DOGE-USD      0
#            DOT-USD     962
#            ETH-USD       0
#            LINK-USD      0
#            LTC-USD       0
#            XLM-USD       0
#            XRP-USD       0
# High       ADA-USD       0
#            BCH-USD       0
#            BTC-USD       0
#            DOGE-USD      0
#            DOT-USD     962
#            ETH-USD       0
#            LINK-USD      0
#            LTC-USD       0
#            XLM-USD       0
#            XRP-USD       0
# Low        ADA-USD       0
#            BCH-USD       0
#            BTC-USD       0
#            DOGE-USD      0
# ...

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>
